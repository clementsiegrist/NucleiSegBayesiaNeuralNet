# %% [markdown]
# <a href="https://colab.research.google.com/github/clementsiegrist/segmentation_probabilisticDL/blob/main/final_withdataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !wget https://raw.githubusercontent.com/clementsiegrist/segmentation_probabilisticDL/main/requirements.txt 
# !pip3 install -r requirements.txt
# !pip3 install --upgrade --force-reinstall --no-deps kaggle

# %%
# %%capture
# !mkdir ~/.kaggle
# !touch ~/.kaggle/kaggle.json


api_token = {"username":"bendidihab","key":"6b534264cbd90d4cc3f040b1894cb226"}
import json
with open('/root/.kaggle/kaggle.json', 'w') as file:
    json.dump(api_token, file)


# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle config set -n path -v{/content}
# !kaggle competitions download -c data-science-bowl-2018
# !unzip /content/{/content}/competitions/data-science-bowl-2018/data-science-bowl-2018.zip
# !mkdir /content/train
# !mv -i /content/stage1_train.zip /content/train
# !cd /content/train && unzip /content/train/stage1_train.zip
# !mkdir /content/data && mkdir /content/data/train && mkdir /content/data/test
# !rm -rf /content/stage1_sample_submission.csv.zip /content/stage1_solution.csv.zip /content/stage1_test.zip /content/stage1_train_labels.csv.zip /content/stage2_sample_submission_final.csv.zip /content/stage2_test_final.zip

# %%
import cv2 as cv
import os
import numpy as np
from google.colab.patches import cv2_imshow

# %%
i = 1
train_percent = 0.7
data_size = 670
dim = (640,480)
path = '/content/train'
list_subfolders_with_paths = [f.path for f in os.scandir(path) if f.is_dir()]
train_size = int(data_size*train_percent)
test_size = data_size - train_size
for sub in list_subfolders_with_paths :
  folder_types = [f.path for f in os.scandir(sub) if f.is_dir()]
  if i < train_size : 
    os.mkdir('data/train/OP'+str(i))
  else :
    os.mkdir('data/test/OP'+str(i))
  for f_type in folder_types :
    if f_type.split('/')[-1] == 'masks': 
      onlyfiles = [f for f in os.listdir(f_type) if os.path.isfile(os.path.join(f_type, f))]
      src = f_type + '/' + onlyfiles[0]
      src1 = cv.imread(src)
      for img in onlyfiles : 
        src2 = cv.imread(f_type + '/' + img)
        alpha = 1
        beta = 1
        src1 = cv.addWeighted(src1, alpha, src2, beta, 0.0)
      img = cv.resize(src1, dim, interpolation = cv.INTER_AREA)
      if i < train_size :
        cv.imwrite('data/train/OP'+str(i)+'/img_' + str(i) + '_class.png',img)
      else :
        cv.imwrite('data/test/OP'+str(i)+'/img_' + str(i) + '_class.png',img)
    if f_type.split('/')[-1] == 'images':
      onlyfiles = [f for f in os.listdir(f_type) if os.path.isfile(os.path.join(f_type, f))]
      img_raw = cv.imread(f_type + '/' + onlyfiles[0])
      img = cv.resize(img_raw, dim, interpolation = cv.INTER_AREA)
      if i < train_size :
        cv.imwrite('data/train/OP'+str(i)+'/img_' + str(i) + '_raw.png',img)
      else :
        cv.imwrite('data/test/OP'+str(i)+'/img_' + str(i) + '_raw.png',img)
  i += 1
# !rm -rf /content/train /content/{

# %%
# %%capture
# !git clone https://github.com/yuta-hi/pytorch-trainer
# !cd pytorch-trainer && python setup.py install
# !git clone https://github.com/IhabBendidi/pytorch_bayesian_unet 
# !cd pytorch_bayesian_unet && pip install -r requirements.txt && python setup.py install


# !cp -r /content/data/train /content/pytorch_bayesian_unet/examples/cellular_segmentation/train
# !cp -r /content/data/test /content/pytorch_bayesian_unet/examples/cellular_segmentation/test

# %%
# !python /content/pytorch_bayesian_unet/examples/cellular_segmentation/preprocess.py
# Out:
# # train images: 467
# 100% 467/467 [00:00<00:00, 2117.91it/s]
# # train labels: 467
# 100% 467/467 [00:02<00:00, 178.77it/s]
# # test images: 203
# 100% 203/203 [00:00<00:00, 1617.91it/s]
# # test labels: 203
# 100% 203/203 [00:01<00:00, 178.83it/s]

# %%
# !python /content/pytorch_bayesian_unet/examples/cellular_segmentation/train_and_test_epistemic.py --iteration 2000

# %%
# !python /content/pytorch_bayesian_unet/examples/cellular_segmentation/train_and_test_epistemic.py --test_on_test
# Out:
# GPU: cuda:0
# # Minibatch-size: 2
#
# Collecting image files: 100%|█████████████████████| 1/1 [00:00<00:00, 87.20it/s]
# Collecting label files: 100%|█████████████████████| 1/1 [00:00<00:00, 89.89it/s]
# Collecting image files: 100%|█████████████████████| 1/1 [00:00<00:00, 93.61it/s]
# Collecting label files: 100%|████████████████████| 1/1 [00:00<00:00, 100.46it/s]
# Collecting image files: 100%|████████████████████| 1/1 [00:00<00:00, 198.95it/s]
# Collecting label files: 100%|████████████████████| 1/1 [00:00<00:00, 220.17it/s]
# # samples:
# -- test: 203
# Loaded a snapshot: logs/predictor_iter_00002000.pth

# %%
# !git clone https://github.com/clementsiegrist/segmentation_probabilisticDL.git
# Out:
# Cloning into 'segmentation_probabilisticDL'...
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (150/150), done.
# remote: Total 505 (delta 4), reused 144 (delta 2), pack-reused 353
# Receiving objects: 100% (505/505), 847.21 MiB | 36.83 MiB/s, done.
# Resolving deltas: 100% (63/63), done.
# Checking out files: 100% (421/421), done.

# %%
# !git clone https://github.com/clementsiegrist/deep_seg.git
# Out:
# Cloning into 'deep_seg'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 12 (delta 2), reused 8 (delta 1), pack-reused 0
# Unpacking objects: 100% (12/12), done.

# %%
 # !pip install keras==2.4 tensorflow==2.3 scikit-learn scikit-image numpy pillow matplotlib imutils pillow opencv-python

# %%
# !unzip /content/segmentation_probabilisticDL/test.zip

# %%
# !unzip /content/segmentation_probabilisticDL/train.zip

# %%
# !mv /content/segmentation_probabilisticDL/validation/ to /content/deep_seg
# Out:
# mv: cannot stat 'to': No such file or directory

# %%
# %cd /content/deep_seg/
# Out:
# /content/deep_seg

# %%
train_path = "/content/deep_seg/train"
validation_path = "/content/deep_seg/validation"
test_path = "/content/deep_seg/test"
test_batch_size = 4
checkpoint_path = '/content/weights'
input_size = (256, 256) 
target_size = (256, 256) # (height, width) of input_size should be divisible by 32
num_class = 2
# fine tuning
train_batch_size = 4
test_batch_size = 4
validation_batch_size = 4
learning_rate = 1e-4
nb_epochs = 10

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
from unet_pipeline.main import main
from unet_pipeline.generator import load_pretrained, train_val_gen
import tensorflow.keras as keras
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-a9e1e3ed8f1b> in <module>()
# ----> 1 from unet_pipeline.main import main
#       2 from unet_pipeline.generator import load_pretrained, train_val_gen
#       3 import tensorflow.keras as keras
#
# /content/deep_seg/unet_pipeline/main.py in <module>()
# ----> 1 from deep_seg.unet_pipeline.generator import load_pretrained
#       2 from deep_seg.unet_pipeline.generator import predict_on_test_and_plot
#       3 from deep_seg.unet_pipeline.generator import plot_results
#       4 checkpoint_path = '/content/weights'
#       5 test_path = "/content/drive/MyDrive/Colab Notebooks/cells/test"
#
# ModuleNotFoundError: No module named 'deep_seg'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import tensorflow.keras as keras
model_name = 'cell_seg.hdf5'
model = main(train_path, train_batch_size, validation_path, validation_batch_size, nb_epochs)
predict_on_test_and_plot(test_path, model_name=model_name, num=98)
# Out:
# Found 502 images belonging to 1 classes.
# Found 502 images belonging to 1 classes.
# Found 68 images belonging to 1 classes.
# Found 68 images belonging to 1 classes.
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 16) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 16) 2320        activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 16) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 16) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 32) 4640        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 32) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 32) 9248        activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 32) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 64)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 128)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 128)  147584      activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 128)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 256)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 256)  590080      activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 256)  0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 16, 16, 256)  0           activation_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 256)  0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 128)  295040      up_sampling2d[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 128)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 256)  0           activation_7[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 128)  295040      concatenate[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 128)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 32, 32, 128)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 128)  0           activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 64)   73792       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 64, 64, 64)   0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 128)  0           activation_5[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 64, 64, 64)   0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 64)   36928       activation_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 64, 64)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 64) 0           activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 32) 18464       up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 128, 128, 32) 0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 64) 0           activation_3[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 32) 18464       concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 128, 128, 32) 0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 32) 9248        activation_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 128, 128, 32) 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 32) 0           activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 16) 4624        up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 256, 256, 16) 0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 32) 0           activation_1[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 16) 4624        concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 256, 256, 16) 0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 16) 2320        activation_20[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 256, 256, 16) 0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 16) 2320        activation_21[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 256, 256, 16) 0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256, 256, 2)  34          activation_22[0][0]
# ==================================================================================================
# Total params: 2,161,042
# Trainable params: 2,161,042
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /content/deep_seg/unet_pipeline/generator.py:190: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/10
# 125/125 [==============================] - ETA: 0s - loss: 0.2568 - accuracy: 0.9987
# Epoch 00001: loss improved from inf to 0.25684, saving model to /content/weights/checkpoint/cell_seg.hdf5
# 125/125 [==============================] - 14s 116ms/step - loss: 0.2568 - accuracy: 0.9987 - val_loss: 0.1685 - val_accuracy: 1.0000
# Epoch 2/10
# 125/125 [==============================] - ETA: 0s - loss: 0.1191 - accuracy: 1.0000
# Epoch 00002: loss improved from 0.25684 to 0.11908, saving model to /content/weights/checkpoint/cell_seg.hdf5
# 125/125 [==============================] - 14s 114ms/step - loss: 0.1191 - accuracy: 1.0000 - val_loss: 0.1269 - val_accuracy: 1.0000
# Epoch 3/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0963 - accuracy: 1.0000
# Epoch 00003: loss improved from 0.11908 to 0.09634, saving model to /content/weights/checkpoint/cell_seg.hdf5
# 125/125 [==============================] - 14s 114ms/step - loss: 0.0963 - accuracy: 1.0000 - val_loss: 0.1094 - val_accuracy: 1.0000
# Epoch 4/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0654 - accuracy: 1.0000
# Epoch 00004: loss improved from 0.09634 to 0.06535, saving model to /content/weights/checkpoint/cell_seg.hdf5
# 125/125 [==============================] - 14s 115ms/step - loss: 0.0654 - accuracy: 1.0000 - val_loss: 0.0801 - val_accuracy: 1.0000
# Epoch 5/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0593 - accuracy: 1.0000
# Epoch 00005: loss improved from 0.06535 to 0.05926, saving model to /content/weights/checkpoint/cell_seg.hdf5
# 125/125 [==============================] - 14s 115ms/step - loss: 0.0593 - accuracy: 1.0000 - val_loss: 0.0599 - val_accuracy: 1.0000
# Epoch 6/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0495 - accuracy: 1.0000
# Epoch 00006: loss improved from 0.05926 to 0.04953, saving model to /content/weights/checkpoint/cell_seg.hdf5
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 7.999999797903001e-05.
# 125/125 [==============================] - 14s 115ms/step - loss: 0.0495 - accuracy: 1.0000 - val_loss: 0.0561 - val_accuracy: 1.0000
# Epoch 7/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0475 - accuracy: 1.0000
# Epoch 00007: loss improved from 0.04953 to 0.04751, saving model to /content/weights/checkpoint/cell_seg.hdf5
# 125/125 [==============================] - 14s 115ms/step - loss: 0.0475 - accuracy: 1.0000 - val_loss: 0.0559 - val_accuracy: 1.0000
# Epoch 8/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0439 - accuracy: 1.0000
# Epoch 00008: loss improved from 0.04751 to 0.04392, saving model to /content/weights/checkpoint/cell_seg.hdf5
# 125/125 [==============================] - 14s 115ms/step - loss: 0.0439 - accuracy: 1.0000 - val_loss: 0.0525 - val_accuracy: 1.0000
# Epoch 9/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0420 - accuracy: 1.0000
# Epoch 00009: loss improved from 0.04392 to 0.04205, saving model to /content/weights/checkpoint/cell_seg.hdf5
# 125/125 [==============================] - 14s 115ms/step - loss: 0.0420 - accuracy: 1.0000 - val_loss: 0.0461 - val_accuracy: 1.0000
# Epoch 10/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0403 - accuracy: 1.0000
# Epoch 00010: loss improved from 0.04205 to 0.04029, saving model to /content/weights/checkpoint/cell_seg.hdf5
# 125/125 [==============================] - 14s 115ms/step - loss: 0.0403 - accuracy: 1.0000 - val_loss: 0.0426 - val_accuracy: 1.0000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3ef16de50612> in <module>()
#       1 import tensorflow.keras as keras
#       2 model_name = 'cell_seg.hdf5'
# ----> 3 model = main(train_path, train_batch_size, validation_path, validation_batch_size, nb_epochs)
#       4 predict_on_test_and_plot(test_path, model_name=model_name, num=98)
#
# /content/deep_seg/unet_pipeline/main.py in main(train_path, train_batch_size, validation_path, validation_batch_size, nb_epochs)
#      31     # model = load_weight_map_unet(train_path, train_generator, validation_generator, validation_batch_size, train_batch_size, nb_epochs, train_image_generator, validation_image_generator)
#      32     plot_results(model)
# ---> 33     predict_on_test_and_plot(model_name=model_name, test_path=test_path, num=96)
#      34     return model
#
# NameError: name 'model_name' is not defined

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
from PIL import Image
import cv2
from unet_pipeline.generator import predict_on_test_and_plot

model_name = 'cell_seg.hdf5'
predict_on_test_and_plot(test_path, model_name=model_name, num=96)
# Out:
# Found 100 images belonging to 1 classes.
# Found 100 images belonging to 1 classes.
# 4/4 [==============================] - 0s 12ms/step
